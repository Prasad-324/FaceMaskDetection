# %%
import cv2 as cv

# %%
haar_cascade = cv.CascadeClassifier('haar_face.xml')
count=0

# %%
capture = cv.VideoCapture(0)

while True:
    ret,frame = capture.read()
    
    faces_rect = haar_cascade.detectMultiScale(frame,1.35,5)
    
    for (x,y,w,h) in faces_rect:
        count=count+1
        name='./Images/FaceMask/' + str(count) + '.jpg'
        print("Creating the image :"+name)
        cv.imwrite(name,frame[y:y+h,x:x+w])
        cv.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)
    cv.imshow("Frame",frame)
    
    cv.waitKey(1) 
    if count>500:
        break
        
capture.release()

cv.destroyAllWindows()
# Out:
# Creating the image :./Images/FaceMask/1.jpg
# Creating the image :./Images/FaceMask/2.jpg
# Creating the image :./Images/FaceMask/3.jpg
# Creating the image :./Images/FaceMask/4.jpg
# Creating the image :./Images/FaceMask/5.jpg
# Creating the image :./Images/FaceMask/6.jpg
# Creating the image :./Images/FaceMask/7.jpg
# Creating the image :./Images/FaceMask/8.jpg
# Creating the image :./Images/FaceMask/9.jpg
# Creating the image :./Images/FaceMask/10.jpg
# Creating the image :./Images/FaceMask/11.jpg
# Creating the image :./Images/FaceMask/12.jpg
# Creating the image :./Images/FaceMask/13.jpg
# Creating the image :./Images/FaceMask/14.jpg
# Creating the image :./Images/FaceMask/15.jpg
# Creating the image :./Images/FaceMask/16.jpg
# Creating the image :./Images/FaceMask/17.jpg
# Creating the image :./Images/FaceMask/18.jpg
# Creating the image :./Images/FaceMask/19.jpg
# Creating the image :./Images/FaceMask/20.jpg
# Creating the image :./Images/FaceMask/21.jpg
# Creating the image :./Images/FaceMask/22.jpg
# Creating the image :./Images/FaceMask/23.jpg
# Creating the image :./Images/FaceMask/24.jpg
# Creating the image :./Images/FaceMask/25.jpg
# Creating the image :./Images/FaceMask/26.jpg
# Creating the image :./Images/FaceMask/27.jpg
# Creating the image :./Images/FaceMask/28.jpg
# Creating the image :./Images/FaceMask/29.jpg
# Creating the image :./Images/FaceMask/30.jpg
# Creating the image :./Images/FaceMask/31.jpg
# Creating the image :./Images/FaceMask/32.jpg
# Creating the image :./Images/FaceMask/33.jpg
# Creating the image :./Images/FaceMask/34.jpg
# Creating the image :./Images/FaceMask/35.jpg
# Creating the image :./Images/FaceMask/36.jpg
# Creating the image :./Images/FaceMask/37.jpg
# Creating the image :./Images/FaceMask/38.jpg
# Creating the image :./Images/FaceMask/39.jpg
# Creating the image :./Images/FaceMask/40.jpg
# Creating the image :./Images/FaceMask/41.jpg
# Creating the image :./Images/FaceMask/42.jpg
# Creating the image :./Images/FaceMask/43.jpg
# Creating the image :./Images/FaceMask/44.jpg
# Creating the image :./Images/FaceMask/45.jpg
# Creating the image :./Images/FaceMask/46.jpg
# Creating the image :./Images/FaceMask/47.jpg
# Creating the image :./Images/FaceMask/48.jpg
# Creating the image :./Images/FaceMask/49.jpg
# Creating the image :./Images/FaceMask/50.jpg
# Creating the image :./Images/FaceMask/51.jpg
# Creating the image :./Images/FaceMask/52.jpg
# Creating the image :./Images/FaceMask/53.jpg
# Creating the image :./Images/FaceMask/54.jpg
# Creating the image :./Images/FaceMask/55.jpg
# Creating the image :./Images/FaceMask/56.jpg
# Creating the image :./Images/FaceMask/57.jpg
# Creating the image :./Images/FaceMask/58.jpg
# Creating the image :./Images/FaceMask/59.jpg
# Creating the image :./Images/FaceMask/60.jpg
# Creating the image :./Images/FaceMask/61.jpg
# Creating the image :./Images/FaceMask/62.jpg
# Creating the image :./Images/FaceMask/63.jpg
# Creating the image :./Images/FaceMask/64.jpg
# Creating the image :./Images/FaceMask/65.jpg
# Creating the image :./Images/FaceMask/66.jpg
# Creating the image :./Images/FaceMask/67.jpg
# Creating the image :./Images/FaceMask/68.jpg
# Creating the image :./Images/FaceMask/69.jpg
# Creating the image :./Images/FaceMask/70.jpg
# Creating the image :./Images/FaceMask/71.jpg
# Creating the image :./Images/FaceMask/72.jpg
# Creating the image :./Images/FaceMask/73.jpg
# Creating the image :./Images/FaceMask/74.jpg
# Creating the image :./Images/FaceMask/75.jpg
# Creating the image :./Images/FaceMask/76.jpg
# Creating the image :./Images/FaceMask/77.jpg
# Creating the image :./Images/FaceMask/78.jpg
# Creating the image :./Images/FaceMask/79.jpg
# Creating the image :./Images/FaceMask/80.jpg
# Creating the image :./Images/FaceMask/81.jpg
# Creating the image :./Images/FaceMask/82.jpg
# Creating the image :./Images/FaceMask/83.jpg
# Creating the image :./Images/FaceMask/84.jpg
# Creating the image :./Images/FaceMask/85.jpg
# Creating the image :./Images/FaceMask/86.jpg
# Creating the image :./Images/FaceMask/87.jpg
# Creating the image :./Images/FaceMask/88.jpg
# Creating the image :./Images/FaceMask/89.jpg
# Creating the image :./Images/FaceMask/90.jpg
# Creating the image :./Images/FaceMask/91.jpg
# Creating the image :./Images/FaceMask/92.jpg
# Creating the image :./Images/FaceMask/93.jpg
# Creating the image :./Images/FaceMask/94.jpg
# Creating the image :./Images/FaceMask/95.jpg
# Creating the image :./Images/FaceMask/96.jpg
# Creating the image :./Images/FaceMask/97.jpg
# Creating the image :./Images/FaceMask/98.jpg
# Creating the image :./Images/FaceMask/99.jpg
# Creating the image :./Images/FaceMask/100.jpg
# Creating the image :./Images/FaceMask/101.jpg
# Creating the image :./Images/FaceMask/102.jpg
# Creating the image :./Images/FaceMask/103.jpg
# Creating the image :./Images/FaceMask/104.jpg
# Creating the image :./Images/FaceMask/105.jpg
# Creating the image :./Images/FaceMask/106.jpg
# Creating the image :./Images/FaceMask/107.jpg
# Creating the image :./Images/FaceMask/108.jpg
# Creating the image :./Images/FaceMask/109.jpg
# Creating the image :./Images/FaceMask/110.jpg
# Creating the image :./Images/FaceMask/111.jpg
# Creating the image :./Images/FaceMask/112.jpg
# Creating the image :./Images/FaceMask/113.jpg
# Creating the image :./Images/FaceMask/114.jpg
# Creating the image :./Images/FaceMask/115.jpg
# Creating the image :./Images/FaceMask/116.jpg
# Creating the image :./Images/FaceMask/117.jpg
# Creating the image :./Images/FaceMask/118.jpg
# Creating the image :./Images/FaceMask/119.jpg
# Creating the image :./Images/FaceMask/120.jpg
# Creating the image :./Images/FaceMask/121.jpg
# Creating the image :./Images/FaceMask/122.jpg
# Creating the image :./Images/FaceMask/123.jpg
# Creating the image :./Images/FaceMask/124.jpg
# Creating the image :./Images/FaceMask/125.jpg
# Creating the image :./Images/FaceMask/126.jpg
# Creating the image :./Images/FaceMask/127.jpg
# Creating the image :./Images/FaceMask/128.jpg
# Creating the image :./Images/FaceMask/129.jpg
# Creating the image :./Images/FaceMask/130.jpg
# Creating the image :./Images/FaceMask/131.jpg
# Creating the image :./Images/FaceMask/132.jpg
# Creating the image :./Images/FaceMask/133.jpg
# Creating the image :./Images/FaceMask/134.jpg
# Creating the image :./Images/FaceMask/135.jpg
# Creating the image :./Images/FaceMask/136.jpg
# Creating the image :./Images/FaceMask/137.jpg
# Creating the image :./Images/FaceMask/138.jpg
# Creating the image :./Images/FaceMask/139.jpg
# Creating the image :./Images/FaceMask/140.jpg
# Creating the image :./Images/FaceMask/141.jpg
# Creating the image :./Images/FaceMask/142.jpg
# Creating the image :./Images/FaceMask/143.jpg
# Creating the image :./Images/FaceMask/144.jpg
# Creating the image :./Images/FaceMask/145.jpg
# Creating the image :./Images/FaceMask/146.jpg
# Creating the image :./Images/FaceMask/147.jpg
# Creating the image :./Images/FaceMask/148.jpg
# Creating the image :./Images/FaceMask/149.jpg
# Creating the image :./Images/FaceMask/150.jpg
# Creating the image :./Images/FaceMask/151.jpg
# Creating the image :./Images/FaceMask/152.jpg
# Creating the image :./Images/FaceMask/153.jpg
# Creating the image :./Images/FaceMask/154.jpg
# Creating the image :./Images/FaceMask/155.jpg
# Creating the image :./Images/FaceMask/156.jpg
# Creating the image :./Images/FaceMask/157.jpg
# Creating the image :./Images/FaceMask/158.jpg
# Creating the image :./Images/FaceMask/159.jpg
# Creating the image :./Images/FaceMask/160.jpg
# Creating the image :./Images/FaceMask/161.jpg
# Creating the image :./Images/FaceMask/162.jpg
# Creating the image :./Images/FaceMask/163.jpg
# Creating the image :./Images/FaceMask/164.jpg
# Creating the image :./Images/FaceMask/165.jpg
# Creating the image :./Images/FaceMask/166.jpg
# Creating the image :./Images/FaceMask/167.jpg
# Creating the image :./Images/FaceMask/168.jpg
# Creating the image :./Images/FaceMask/169.jpg
# Creating the image :./Images/FaceMask/170.jpg
# Creating the image :./Images/FaceMask/171.jpg
# Creating the image :./Images/FaceMask/172.jpg
# Creating the image :./Images/FaceMask/173.jpg
# Creating the image :./Images/FaceMask/174.jpg
# Creating the image :./Images/FaceMask/175.jpg
# Creating the image :./Images/FaceMask/176.jpg
# Creating the image :./Images/FaceMask/177.jpg
# Creating the image :./Images/FaceMask/178.jpg
# Creating the image :./Images/FaceMask/179.jpg
# Creating the image :./Images/FaceMask/180.jpg
# Creating the image :./Images/FaceMask/181.jpg
# Creating the image :./Images/FaceMask/182.jpg
# Creating the image :./Images/FaceMask/183.jpg
# Creating the image :./Images/FaceMask/184.jpg
# Creating the image :./Images/FaceMask/185.jpg
# Creating the image :./Images/FaceMask/186.jpg
# Creating the image :./Images/FaceMask/187.jpg
# Creating the image :./Images/FaceMask/188.jpg
# Creating the image :./Images/FaceMask/189.jpg
# Creating the image :./Images/FaceMask/190.jpg
# Creating the image :./Images/FaceMask/191.jpg
# Creating the image :./Images/FaceMask/192.jpg
# Creating the image :./Images/FaceMask/193.jpg
# Creating the image :./Images/FaceMask/194.jpg
# Creating the image :./Images/FaceMask/195.jpg
# Creating the image :./Images/FaceMask/196.jpg
# Creating the image :./Images/FaceMask/197.jpg
# Creating the image :./Images/FaceMask/198.jpg
# Creating the image :./Images/FaceMask/199.jpg
# Creating the image :./Images/FaceMask/200.jpg
# Creating the image :./Images/FaceMask/201.jpg
# Creating the image :./Images/FaceMask/202.jpg
# Creating the image :./Images/FaceMask/203.jpg
# Creating the image :./Images/FaceMask/204.jpg
# Creating the image :./Images/FaceMask/205.jpg
# Creating the image :./Images/FaceMask/206.jpg
# Creating the image :./Images/FaceMask/207.jpg
# Creating the image :./Images/FaceMask/208.jpg
# Creating the image :./Images/FaceMask/209.jpg
# Creating the image :./Images/FaceMask/210.jpg
# Creating the image :./Images/FaceMask/211.jpg
# Creating the image :./Images/FaceMask/212.jpg
# Creating the image :./Images/FaceMask/213.jpg
# Creating the image :./Images/FaceMask/214.jpg
# Creating the image :./Images/FaceMask/215.jpg
# Creating the image :./Images/FaceMask/216.jpg
# Creating the image :./Images/FaceMask/217.jpg
# Creating the image :./Images/FaceMask/218.jpg
# Creating the image :./Images/FaceMask/219.jpg
# Creating the image :./Images/FaceMask/220.jpg
# Creating the image :./Images/FaceMask/221.jpg
# Creating the image :./Images/FaceMask/222.jpg
# Creating the image :./Images/FaceMask/223.jpg
# Creating the image :./Images/FaceMask/224.jpg
# Creating the image :./Images/FaceMask/225.jpg
# Creating the image :./Images/FaceMask/226.jpg
# Creating the image :./Images/FaceMask/227.jpg
# Creating the image :./Images/FaceMask/228.jpg
# Creating the image :./Images/FaceMask/229.jpg
# Creating the image :./Images/FaceMask/230.jpg
# Creating the image :./Images/FaceMask/231.jpg
# Creating the image :./Images/FaceMask/232.jpg
# Creating the image :./Images/FaceMask/233.jpg
# Creating the image :./Images/FaceMask/234.jpg
# Creating the image :./Images/FaceMask/235.jpg
# Creating the image :./Images/FaceMask/236.jpg
# Creating the image :./Images/FaceMask/237.jpg
# Creating the image :./Images/FaceMask/238.jpg
# Creating the image :./Images/FaceMask/239.jpg
# Creating the image :./Images/FaceMask/240.jpg
# Creating the image :./Images/FaceMask/241.jpg
# Creating the image :./Images/FaceMask/242.jpg
# Creating the image :./Images/FaceMask/243.jpg
# Creating the image :./Images/FaceMask/244.jpg
# Creating the image :./Images/FaceMask/245.jpg
# Creating the image :./Images/FaceMask/246.jpg
# Creating the image :./Images/FaceMask/247.jpg
# Creating the image :./Images/FaceMask/248.jpg
# Creating the image :./Images/FaceMask/249.jpg
# Creating the image :./Images/FaceMask/250.jpg
# Creating the image :./Images/FaceMask/251.jpg
# Creating the image :./Images/FaceMask/252.jpg
# Creating the image :./Images/FaceMask/253.jpg
# Creating the image :./Images/FaceMask/254.jpg
# Creating the image :./Images/FaceMask/255.jpg
# Creating the image :./Images/FaceMask/256.jpg
# Creating the image :./Images/FaceMask/257.jpg
# Creating the image :./Images/FaceMask/258.jpg
# Creating the image :./Images/FaceMask/259.jpg
# Creating the image :./Images/FaceMask/260.jpg
# Creating the image :./Images/FaceMask/261.jpg
# Creating the image :./Images/FaceMask/262.jpg
# Creating the image :./Images/FaceMask/263.jpg
# Creating the image :./Images/FaceMask/264.jpg
# Creating the image :./Images/FaceMask/265.jpg
# Creating the image :./Images/FaceMask/266.jpg
# Creating the image :./Images/FaceMask/267.jpg
# Creating the image :./Images/FaceMask/268.jpg
# Creating the image :./Images/FaceMask/269.jpg
# Creating the image :./Images/FaceMask/270.jpg
# Creating the image :./Images/FaceMask/271.jpg
# Creating the image :./Images/FaceMask/272.jpg
# Creating the image :./Images/FaceMask/273.jpg
# Creating the image :./Images/FaceMask/274.jpg
# Creating the image :./Images/FaceMask/275.jpg
# Creating the image :./Images/FaceMask/276.jpg
# Creating the image :./Images/FaceMask/277.jpg
# Creating the image :./Images/FaceMask/278.jpg
# Creating the image :./Images/FaceMask/279.jpg
# Creating the image :./Images/FaceMask/280.jpg
# Creating the image :./Images/FaceMask/281.jpg
# Creating the image :./Images/FaceMask/282.jpg
# Creating the image :./Images/FaceMask/283.jpg
# Creating the image :./Images/FaceMask/284.jpg
# Creating the image :./Images/FaceMask/285.jpg
# Creating the image :./Images/FaceMask/286.jpg
# Creating the image :./Images/FaceMask/287.jpg
# Creating the image :./Images/FaceMask/288.jpg
# Creating the image :./Images/FaceMask/289.jpg
# Creating the image :./Images/FaceMask/290.jpg
# Creating the image :./Images/FaceMask/291.jpg
# Creating the image :./Images/FaceMask/292.jpg
# Creating the image :./Images/FaceMask/293.jpg
# Creating the image :./Images/FaceMask/294.jpg
# Creating the image :./Images/FaceMask/295.jpg
# Creating the image :./Images/FaceMask/296.jpg
# Creating the image :./Images/FaceMask/297.jpg
# Creating the image :./Images/FaceMask/298.jpg
# Creating the image :./Images/FaceMask/299.jpg
# Creating the image :./Images/FaceMask/300.jpg
# Creating the image :./Images/FaceMask/301.jpg
# Creating the image :./Images/FaceMask/302.jpg
# Creating the image :./Images/FaceMask/303.jpg
# Creating the image :./Images/FaceMask/304.jpg
# Creating the image :./Images/FaceMask/305.jpg
# Creating the image :./Images/FaceMask/306.jpg
# Creating the image :./Images/FaceMask/307.jpg
# Creating the image :./Images/FaceMask/308.jpg
# Creating the image :./Images/FaceMask/309.jpg
# Creating the image :./Images/FaceMask/310.jpg
# Creating the image :./Images/FaceMask/311.jpg
# Creating the image :./Images/FaceMask/312.jpg
# Creating the image :./Images/FaceMask/313.jpg
# Creating the image :./Images/FaceMask/314.jpg
# Creating the image :./Images/FaceMask/315.jpg
# Creating the image :./Images/FaceMask/316.jpg
# Creating the image :./Images/FaceMask/317.jpg
# Creating the image :./Images/FaceMask/318.jpg
# Creating the image :./Images/FaceMask/319.jpg
# Creating the image :./Images/FaceMask/320.jpg
# Creating the image :./Images/FaceMask/321.jpg
# Creating the image :./Images/FaceMask/322.jpg
# Creating the image :./Images/FaceMask/323.jpg
# Creating the image :./Images/FaceMask/324.jpg
# Creating the image :./Images/FaceMask/325.jpg
# Creating the image :./Images/FaceMask/326.jpg
# Creating the image :./Images/FaceMask/327.jpg
# Creating the image :./Images/FaceMask/328.jpg
# Creating the image :./Images/FaceMask/329.jpg
# Creating the image :./Images/FaceMask/330.jpg
# Creating the image :./Images/FaceMask/331.jpg
# Creating the image :./Images/FaceMask/332.jpg
# Creating the image :./Images/FaceMask/333.jpg
# Creating the image :./Images/FaceMask/334.jpg
# Creating the image :./Images/FaceMask/335.jpg
# Creating the image :./Images/FaceMask/336.jpg
# Creating the image :./Images/FaceMask/337.jpg
# Creating the image :./Images/FaceMask/338.jpg
# Creating the image :./Images/FaceMask/339.jpg
# Creating the image :./Images/FaceMask/340.jpg
# Creating the image :./Images/FaceMask/341.jpg
# Creating the image :./Images/FaceMask/342.jpg
# Creating the image :./Images/FaceMask/343.jpg
# Creating the image :./Images/FaceMask/344.jpg
# Creating the image :./Images/FaceMask/345.jpg
# Creating the image :./Images/FaceMask/346.jpg
# Creating the image :./Images/FaceMask/347.jpg
# Creating the image :./Images/FaceMask/348.jpg
# Creating the image :./Images/FaceMask/349.jpg
# Creating the image :./Images/FaceMask/350.jpg
# Creating the image :./Images/FaceMask/351.jpg
# Creating the image :./Images/FaceMask/352.jpg
# Creating the image :./Images/FaceMask/353.jpg
# Creating the image :./Images/FaceMask/354.jpg
# Creating the image :./Images/FaceMask/355.jpg
# Creating the image :./Images/FaceMask/356.jpg
# Creating the image :./Images/FaceMask/357.jpg
# Creating the image :./Images/FaceMask/358.jpg
# Creating the image :./Images/FaceMask/359.jpg
# Creating the image :./Images/FaceMask/360.jpg
# Creating the image :./Images/FaceMask/361.jpg
# Creating the image :./Images/FaceMask/362.jpg
# Creating the image :./Images/FaceMask/363.jpg
# Creating the image :./Images/FaceMask/364.jpg
# Creating the image :./Images/FaceMask/365.jpg
# Creating the image :./Images/FaceMask/366.jpg
# Creating the image :./Images/FaceMask/367.jpg
# Creating the image :./Images/FaceMask/368.jpg
# Creating the image :./Images/FaceMask/369.jpg
# Creating the image :./Images/FaceMask/370.jpg
# Creating the image :./Images/FaceMask/371.jpg
# Creating the image :./Images/FaceMask/372.jpg
# Creating the image :./Images/FaceMask/373.jpg
# Creating the image :./Images/FaceMask/374.jpg
# Creating the image :./Images/FaceMask/375.jpg
# Creating the image :./Images/FaceMask/376.jpg
# Creating the image :./Images/FaceMask/377.jpg
# Creating the image :./Images/FaceMask/378.jpg
# Creating the image :./Images/FaceMask/379.jpg
# Creating the image :./Images/FaceMask/380.jpg
# Creating the image :./Images/FaceMask/381.jpg
# Creating the image :./Images/FaceMask/382.jpg
# Creating the image :./Images/FaceMask/383.jpg
# Creating the image :./Images/FaceMask/384.jpg
# Creating the image :./Images/FaceMask/385.jpg
# Creating the image :./Images/FaceMask/386.jpg
# Creating the image :./Images/FaceMask/387.jpg
# Creating the image :./Images/FaceMask/388.jpg
# Creating the image :./Images/FaceMask/389.jpg
# Creating the image :./Images/FaceMask/390.jpg
# Creating the image :./Images/FaceMask/391.jpg
# Creating the image :./Images/FaceMask/392.jpg
# Creating the image :./Images/FaceMask/393.jpg
# Creating the image :./Images/FaceMask/394.jpg
# Creating the image :./Images/FaceMask/395.jpg
# Creating the image :./Images/FaceMask/396.jpg
# Creating the image :./Images/FaceMask/397.jpg
# Creating the image :./Images/FaceMask/398.jpg
# Creating the image :./Images/FaceMask/399.jpg
# Creating the image :./Images/FaceMask/400.jpg
# Creating the image :./Images/FaceMask/401.jpg
# Creating the image :./Images/FaceMask/402.jpg
# Creating the image :./Images/FaceMask/403.jpg
# Creating the image :./Images/FaceMask/404.jpg
# Creating the image :./Images/FaceMask/405.jpg
# Creating the image :./Images/FaceMask/406.jpg
# Creating the image :./Images/FaceMask/407.jpg
# Creating the image :./Images/FaceMask/408.jpg
# Creating the image :./Images/FaceMask/409.jpg
# Creating the image :./Images/FaceMask/410.jpg
# Creating the image :./Images/FaceMask/411.jpg
# Creating the image :./Images/FaceMask/412.jpg
# Creating the image :./Images/FaceMask/413.jpg
# Creating the image :./Images/FaceMask/414.jpg
# Creating the image :./Images/FaceMask/415.jpg
# Creating the image :./Images/FaceMask/416.jpg
# Creating the image :./Images/FaceMask/417.jpg
# Creating the image :./Images/FaceMask/418.jpg
# Creating the image :./Images/FaceMask/419.jpg
# Creating the image :./Images/FaceMask/420.jpg
# Creating the image :./Images/FaceMask/421.jpg
# Creating the image :./Images/FaceMask/422.jpg
# Creating the image :./Images/FaceMask/423.jpg
# Creating the image :./Images/FaceMask/424.jpg
# Creating the image :./Images/FaceMask/425.jpg
# Creating the image :./Images/FaceMask/426.jpg
# Creating the image :./Images/FaceMask/427.jpg
# Creating the image :./Images/FaceMask/428.jpg
# Creating the image :./Images/FaceMask/429.jpg
# Creating the image :./Images/FaceMask/430.jpg
# Creating the image :./Images/FaceMask/431.jpg
# Creating the image :./Images/FaceMask/432.jpg
# Creating the image :./Images/FaceMask/433.jpg
# Creating the image :./Images/FaceMask/434.jpg
# Creating the image :./Images/FaceMask/435.jpg
# Creating the image :./Images/FaceMask/436.jpg
# Creating the image :./Images/FaceMask/437.jpg
# Creating the image :./Images/FaceMask/438.jpg
# Creating the image :./Images/FaceMask/439.jpg
# Creating the image :./Images/FaceMask/440.jpg
# Creating the image :./Images/FaceMask/441.jpg
# Creating the image :./Images/FaceMask/442.jpg
# Creating the image :./Images/FaceMask/443.jpg
# Creating the image :./Images/FaceMask/444.jpg
# Creating the image :./Images/FaceMask/445.jpg
# Creating the image :./Images/FaceMask/446.jpg
# Creating the image :./Images/FaceMask/447.jpg
# Creating the image :./Images/FaceMask/448.jpg
# Creating the image :./Images/FaceMask/449.jpg
# Creating the image :./Images/FaceMask/450.jpg
# Creating the image :./Images/FaceMask/451.jpg
# Creating the image :./Images/FaceMask/452.jpg
# Creating the image :./Images/FaceMask/453.jpg
# Creating the image :./Images/FaceMask/454.jpg
# Creating the image :./Images/FaceMask/455.jpg
# Creating the image :./Images/FaceMask/456.jpg
# Creating the image :./Images/FaceMask/457.jpg
# Creating the image :./Images/FaceMask/458.jpg
# Creating the image :./Images/FaceMask/459.jpg
# Creating the image :./Images/FaceMask/460.jpg
# Creating the image :./Images/FaceMask/461.jpg
# Creating the image :./Images/FaceMask/462.jpg
# Creating the image :./Images/FaceMask/463.jpg
# Creating the image :./Images/FaceMask/464.jpg
# Creating the image :./Images/FaceMask/465.jpg
# Creating the image :./Images/FaceMask/466.jpg
# Creating the image :./Images/FaceMask/467.jpg
# Creating the image :./Images/FaceMask/468.jpg
# Creating the image :./Images/FaceMask/469.jpg
# Creating the image :./Images/FaceMask/470.jpg
# Creating the image :./Images/FaceMask/471.jpg
# Creating the image :./Images/FaceMask/472.jpg
# Creating the image :./Images/FaceMask/473.jpg
# Creating the image :./Images/FaceMask/474.jpg
# Creating the image :./Images/FaceMask/475.jpg
# Creating the image :./Images/FaceMask/476.jpg
# Creating the image :./Images/FaceMask/477.jpg
# Creating the image :./Images/FaceMask/478.jpg
# Creating the image :./Images/FaceMask/479.jpg
# Creating the image :./Images/FaceMask/480.jpg
# Creating the image :./Images/FaceMask/481.jpg
# Creating the image :./Images/FaceMask/482.jpg
# Creating the image :./Images/FaceMask/483.jpg
# Creating the image :./Images/FaceMask/484.jpg
# Creating the image :./Images/FaceMask/485.jpg
# Creating the image :./Images/FaceMask/486.jpg
# Creating the image :./Images/FaceMask/487.jpg
# Creating the image :./Images/FaceMask/488.jpg
# Creating the image :./Images/FaceMask/489.jpg
# Creating the image :./Images/FaceMask/490.jpg
# Creating the image :./Images/FaceMask/491.jpg
# Creating the image :./Images/FaceMask/492.jpg
# Creating the image :./Images/FaceMask/493.jpg
# Creating the image :./Images/FaceMask/494.jpg
# Creating the image :./Images/FaceMask/495.jpg
# Creating the image :./Images/FaceMask/496.jpg
# Creating the image :./Images/FaceMask/497.jpg
# Creating the image :./Images/FaceMask/498.jpg
# Creating the image :./Images/FaceMask/499.jpg
# Creating the image :./Images/FaceMask/500.jpg
# Creating the image :./Images/FaceMask/501.jpg

# %%
import warnings
warnings.filterwarnings('ignore')
import cv2 as cv
import numpy as np
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D,Dense,MaxPooling2D,Activation,Dropout,Flatten
from tensorflow.keras.optimizers import Adam

# %%
DIM = (32,32,3)
path = 'Images'
images=[]
classNo=[]
myList = os.listdir(path)
numClasses = len(myList)

# %%
##Preproccessing of Images
for x in range(0,numClasses):
    myList = os.listdir(path+"/"+str(x))
    
    for y in myList:
        curImg = cv.imread(path+"/"+str(x)+"/"+y)
        curImg = cv.resize(curImg,(DIM[0],DIM[1]))
        images.append(curImg)
        classNo.append(x)
    print(x)
    
images=np.array(images)
classNo=np.array(classNo)
# Out:
# 0
# 1

# %%
len(images)
# Out:
# 1002

# %%
X_train,X_test,Y_train,Y_test = train_test_split(images,classNo,test_size=0.2)
X_train,X_validation,Y_train,Y_validation = train_test_split(images,classNo,test_size=0.2)

# %%
plt.bar(range(0,numClasses),(len(X_train),len(Y_train)))
plt.show()

# %%
def preprocessing(img):
    img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    img = cv.equalizeHist(img)
    img=img/255
    return img

# %%
X_train = np.array(list(map(preprocessing,X_train)))
X_test = np.array(list(map(preprocessing,X_test)))
X_validation = np.array(list(map(preprocessing,X_validation)))

# %%
X_train.shape
# Out:
# (801, 32, 32)

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],X_train.shape[2],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],X_test.shape[2],1)
X_validation = X_validation.reshape(X_validation.shape[0],X_validation.shape[1],X_validation.shape[2],1)

# %%
X_train.shape
# Out:
# (801, 32, 32, 1)

# %%
dataGen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    shear_range=0.1,
    rotation_range=10)

# %%
dataGen.fit(X_train)

# %%
Y_train = to_categorical(Y_train,num_classes=numClasses)
Y_test = to_categorical(Y_test,num_classes=numClasses)
Y_validation = to_categorical(Y_validation,num_classes=numClasses)

# %%
def Model():
    model = Sequential()
    model.add(Conv2D(32,(3,3),input_shape=(DIM[0],DIM[1],1),activation='relu'))
    model.add(Conv2D(32,(3,3),activation='relu'))
    model.add(MaxPooling2D((2,2)))
              
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPooling2D((2,2)))
    model.add(Dropout(0.5))
              
    model.add(Flatten())
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(numClasses,activation='softmax'))
    
    model.compile(Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])   

    return model

# %%
model = Model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 5, 5, 64)          0
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 64)                102464
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 167,586
# Trainable params: 167,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(dataGen.flow(X_train,Y_train,batch_size=32),
                                          steps_per_epoch=25,
                                          epochs=5,
                                          validation_data=(X_validation,Y_validation),
                                          shuffle=True)
# Out:
# Epoch 1/5
# 25/25 [==============================] - 3s 88ms/step - loss: 0.6750 - accuracy: 0.5800 - val_loss: 0.6241 - val_accuracy: 0.4627
# Epoch 2/5
# 25/25 [==============================] - 2s 67ms/step - loss: 0.5315 - accuracy: 0.7334 - val_loss: 0.3422 - val_accuracy: 1.0000
# Epoch 3/5
# 25/25 [==============================] - 2s 67ms/step - loss: 0.2239 - accuracy: 0.9194 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 4/5
# 25/25 [==============================] - 2s 68ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 5.2641e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 25/25 [==============================] - 2s 66ms/step - loss: 0.0188 - accuracy: 0.9935 - val_loss: 8.9375e-06 - val_accuracy: 1.0000

# %%
model.save('MaskModel.h5')

# %%
##Testing

# %%
import cv2 as cv
from keras.models import load_model

# %%
haar_cascade = cv.CascadeClassifier('haar_face.xml')
model = load_model('MaskModel.h5')

# %%
def preprocessing(img):
    img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    img = cv.equalizeHist(img)
    img = img/255
    return img

# %%
def get_className(classNo):
    if classNo==0:
        return "Mask"
    elif classNo==1:
        return "NO Mask"

# %%
threshold = 0.9

# %%
capture = cv.VideoCapture(0)

while True:
    ret,frames = capture.read()
    faces_rect = haar_cascade.detectMultiScale(frames,1.3,5)
    
    for x,y,w,h in faces_rect:
        crop_img = frames[y:y+h,x:x+w]
        img = cv.resize(crop_img,(32,32))
        img = preprocessing(img)
        img = img.reshape(1,32,32,1)
        
        classIndex = np.argmax(model.predict(img), axis=-1)
        confidence = np.max(model.predict(img))
        
        if confidence > threshold:
            if classIndex == 0:
                cv.rectangle(frames,(x,y),(x+w,y+h),(0,255,0),2)
                cv.putText(frames,str(str(get_className(classIndex))+":"+str(confidence)),(x,y-10),cv.FONT_HERSHEY_COMPLEX,1.0,(255,255,255),thickness=2)
            if classIndex == 1:
                cv.rectangle(frames,(x,y),(x+w,y+h),(0,0,255),2)
                cv.putText(frames,str(str(get_className(classIndex)) +":"+str(confidence)),(x,y-10),cv.FONT_HERSHEY_COMPLEX,1.0,(255,255,255),thickness=2)
        cv.imshow("Result",frames)
        
    if cv.waitKey(1) & 0xFF == ord('d'):
        break
    
capture.release()
cv.destroyAllWindows()

# %%
capture.release()
